# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt
import numpy as np
from scipy import stats
from random import randint

# import seaborn
import seaborn as sns

# %% [markdown]
# ### 1. A bank found that the average number of cars waiting during the noon hour at a drive-up window follows a Poisson distribution with a mean of 2 cars. Make a chart of this distribution and answer these questions concerning the probability of cars waiting at the drive-up window.

# %%
# simulation creating the random numbers im going to use.

# %%
poisson_bank_test = poisson_bank.rvs(10000)

# %%
poisson_bank = stats.poisson(2)

# %%
sns.set(color_codes=True)
# settings for seaborn plot sizes
sns.set(rc={'figure.figsize':(5,5)})
from scipy.stats import poisson
data_poisson = poisson.rvs(mu=2, size=10000)

# %%
data_poisson
# Out:
# array([0, 0, 2, ..., 4, 1, 3])

# %% [markdown]
# ### What is the probability that no cars drive up in the noon hour?

# %%
poisson_bank.cdf(0)
# Out:
# 0.1353352832366127

# %%
#simulation

# %%
(poisson_bank_test == 0).mean()
# Out:
# 0.1355

# %% [markdown]
# ### What is the probability that 3 or more cars come through the drive through?

# %%
poisson_bank.sf(2)
# Out:
# 0.32332358381693654

# %%
# simulation

# %%
(poisson_bank_test >= 3).mean()
# Out:
# 0.3269

# %% [markdown]
# ### How likely is it that the drive through gets at least 1 car?

# %%
poisson_bank.sf(0)
# Out:
# 0.8646647167633873

# %%
#simulation

# %%
(poisson_bank_test >= 1).mean()
# Out:
# 0.8645

# %% [markdown]
# ### 2. Grades of State University graduates are normally distributed with a mean of 3.0 and a standard deviation of .3. Calculate the following:

# %%
uni_grades = stats.norm(3,.3)

# %%
n_simulations = 100_000

# %%
uni_grades_test = np.random.normal(loc = 3, scale = .3,size = (n_simulations))

# %% [markdown]
# ### What grade point average is required to be in the top 5% of the graduating class?

# %%
uni_grades.isf(.05)
# Out:
# 3.4934560880854417

# %%
#expiriment below

# %%
tester = uni_grades.isf(.05)

# %%
(uni_grades_test > tester).mean()
# Out:
# 0.05026

# %% [markdown]
# ### What GPA constitutes the bottom 15% of the class?

# %%
uni_grades.ppf(.15)
# Out:
# 2.689069983151863

# %%
# Expiriment below

# %%
tester = uni_grades.ppf(.15)

# %%
(uni_grades_test < tester).mean()
# Out:
# 0.14968

# %% [markdown]
# ### An eccentric alumnus left scholarship money for students in the third decile from the bottom of their class. Determine the range of the third decile. Would a student with a 2.8 grade point average qualify for this scholarship?

# %%
uni_grades.cdf(2.8)
# Out:
# 0.2524925375469227

# %%
uni_grades.ppf(.2)
# Out:
# 2.7475136299281258

# %%
uni_grades.ppf(.3)
# Out:
# 2.842679846187588

# %%
# Yes the student would because he falls in the 20-30% range and he falls between 2.74 and 2.84

# %%
#simulation

# %%
(uni_grades_test < 2.8).mean()
# Out:
# 0.25132

# %% [markdown]
# ### If I have a GPA of 3.5, what percentile am I in?

# %%
uni_grades.cdf(3.5)
# Out:
# 0.9522096477271853

# %%
#simulation

# %%
(uni_grades_test < 3.5).mean()
# Out:
# 0.95189

# %% [markdown]
# ### 3. A marketing website has an average click-through rate of 2%. One day they observe 4326 visitors and 97 click-throughs. How likely is it that this many people or more click through?

# %%
stats.binom(4326, .02).sf(96)
# Out:
# 0.1397582363130086

# %%
# simulation

# %%
outcomes = [0,1]
n_simulations = 50_000
n_trials = 4326
website = np.random.choice(outcomes,  size=(n_simulations,n_trials), p=[.98,.02])

# %%
website = website.sum(axis = 1)

# %%
(website >= 97).mean()
# Out:
# 0.13832

# %% [markdown]
# ### 4. You are working on some statistics homework consisting of 100 questions where all of the answers are a probability rounded to the hundreths place. Looking to save time, you put down random probabilities as the answer to each question.

# %%
stats_quiz = stats.randint(1,101)

# %%
stats_quiz.rvs(100)
# Out:
# array([30, 85, 77, 41, 34, 27, 46, 99, 17, 29, 89, 85, 11, 91, 26, 86, 52,
#        66, 17, 61, 90, 38, 60, 37, 64, 10, 85, 46, 46, 24, 24, 76, 95,  5,
#        73, 70, 86, 50, 80, 69, 21, 29, 72, 97, 91,  8, 74, 97,  8, 89,  6,
#        34, 60,  1, 39, 38, 35, 27, 77,  9, 99, 60, 93, 24, 30, 60, 14, 54,
#        30, 17, 65,  7, 77, 37, 84, 60, 62, 43, 29, 88,  7, 45, 86, 17, 98,
#        46, 64, 93, 84, 70, 18, 27, 91, 81, 17,  5, 11, 18, 44, 61])

# %%
# simulation

# %%
outcomes = [0,1]
n_simulations = 100_000
n_trials = 60
stats_quiz = np.random.choice(outcomes,  size=(n_simulations,n_trials), p=[100/101,1/101])

# %%
stats_quiz = stats_quiz.sum(axis = 1)

# %%
(stats_quiz >= 1).mean()
# Out:
# 0.44981

# %% [markdown]
# ### What is the probability that at least one of your first 60 answers is correct?

# %%
stats_quiz = stats.binom(60,1/101)

# %%
stats_quiz.sf(0)
# Out:
# 0.44955038406224

# %% [markdown]
# ### 5. The codeup staff tends to get upset when the student break area is not cleaned up. Suppose that there's a 3% chance that any one student cleans the break area when they visit it, and, on any given day, about 90% of the 3 active cohorts of 22 students visit the break area. How likely is it that the break area gets cleaned up each day? How likely is it that it goes two days without getting cleaned up? All week?

# %%
#chance of getting cleaned each day

# %%
stats.binom(59,.03).sf(0)
# Out:
# 0.8342199288437355

# %%
clean_rate = stats.binom(59,.03).sf(0)

# %%
stats.binom(2,clean_rate).pmf(0)
# Out:
# 0.02748303199257611

# %%
stats.binom(5,clean_rate).pmf(0)
# Out:
# 0.0001252165138809122

# %%
# Tested through experimentation below

# %%
outcomes = [0,1]
n_simulations = 100_000
n_trials = 59
codeup_clean = np.random.choice(outcomes,  size=(n_simulations,n_trials), p=[.97,.03])

# %%
codeup_clean = codeup_clean.sum(axis = 1)

# %%
(codeup_clean >= 1).mean()
# Out:
# 0.83518

# %%
outcomes = [0,1]
n_simulations = 100_000
n_trials = 118
codeup_clean = np.random.choice(outcomes,  size=(n_simulations,n_trials), p=[.97,.03])

# %%
codeup_clean = codeup_clean.sum(axis = 1)

# %%
(codeup_clean < 1).mean()
# Out:
# 0.0281

# %%
outcomes = [0,1]
n_simulations = 100_000
n_trials = 295
codeup_clean = np.random.choice(outcomes,  size=(n_simulations,n_trials), p=[.97,.03])

# %%
codeup_clean = codeup_clean.sum(axis = 1)

# %%
1- (codeup_clean > 1).mean()
# Out:
# 0.0011999999999999789

# %% [markdown]
# ### 6. You want to get lunch at La Panaderia, but notice that the line is usually very long at lunchtime. After several weeks of careful observation, you notice that the average number of people in line when your lunch break starts is normally distributed with a mean of 15 and standard deviation of 3. If it takes 2 minutes for each person to order, and 10 minutes from ordering to getting your food, what is the likelihood that you have at least 15 minutes left to eat your food before you have to go back to class? Assume you have one hour for lunch, and ignore travel time to and from La Panaderia.

# %%
la_panaderia = stats.norm(15,3)

# %%
17 * 2 + 10
# Out:
# 44

# %%
1 - la_panaderia.sf(17)
# Out:
# 0.7475074624530771

# %%
# Tested through experimentation below

# %%
people_in_line = np.random.normal(loc = 15, scale = 3,size = (n_simulations))

# %%
(people_in_line < 17).mean()
# Out:
# 0.74676

# %% [markdown]
# ### 7. Connect to the employees database and find the average salary of current employees, along with the standard deviation. For the following questions, calculate the answer based on modeling the employees salaries with a normal distribution defined by the calculated mean and standard deviation then compare this answer to the actual values present in the salaries dataset.

# %%
from env import host, user, password

# %%
def get_db_url(user,password,host,database):
    return (f"mysql+pymysql://{user}:{password}@{host}/{database}")

# %%
url = get_db_url(user,password,host,database = "employees")

# %%
query = '''
SELECT *
FROM employees
JOIN salaries USING(emp_no)
WHERE salaries.to_date > NOW();
'''
employees = pd.read_sql(query,url)
employees
# Out:
#         emp_no  birth_date first_name last_name gender   hire_date  salary  \
# 0        10001  1953-09-02     Georgi   Facello      M  1986-06-26   88958
# 1        10002  1964-06-02    Bezalel    Simmel      F  1985-11-21   72527
# 2        10003  1959-12-03      Parto   Bamford      M  1986-08-28   43311
# 3        10004  1954-05-01  Chirstian   Koblick      M  1986-12-01   74057
# 4        10005  1955-01-21    Kyoichi  Maliniak      M  1989-09-12   94692
# ...        ...         ...        ...       ...    ...         ...     ...
# 240119  499995  1958-09-24     Dekang  Lichtner      F  1993-01-12   52868
# 240120  499996  1953-03-07       Zito      Baaz      M  1990-09-27   69501
# 240121  499997  1961-08-03    Berhard    Lenart      M  1986-04-21   83441
# 240122  499998  1956-09-05   Patricia   Breugel      M  1993-10-13   55003
# 240123  499999  1958-05-01     Sachin   Tsukuda      M  1997-11-30   77303
#
#          from_date     to_date
# 0       2002-06-22  9999-01-01
# ...

# %%
stats.norm(employees.salary)

# %%
# STANDARD DEV = 17309.95933634675

# %%
# MEAN/AVG = 72012.2359

# %%
employees_test = np.random.normal(loc = 72012.23 , scale =17309.95,size = (n_simulations))

# %% [markdown]
# ### What percent of employees earn less than 60,000?

# %%
stats.norm(72012,17310).cdf(60000).mean()
# Out:
# 0.2438617554963023

# %%
# sql percent = ~27%

# %%
# simulation

# %%
(employees_test < 60000).mean()
# Out:
# 0.24618

# %% [markdown]
# ### What percent of employees earn more than 95,000?

# %%
stats.norm(72012,17310).sf(95000).mean()
# Out:
# 0.09208599994106093

# %%
# sql percent = ~10.8%

# %%
# simulation

# %%
(employees_test > 95000).mean()
# Out:
# 0.09116

# %% [markdown]
# ### What percent of employees earn between 65,000 and 80,000?

# %%
bottom = stats.norm(72012,17310).cdf(65000).mean()

# %%
top = 1 - stats.norm(72012,17310).sf(80000).mean()

# %%
top - bottom
# Out:
# 0.335060363819384

# %%
# sql percent = ~32.5%

# %%
# simulation

# %%
series = pd.Series(employees_test)

# %%
series.head()
# Out:
# 0     63496.388424
# 1     42078.369376
# 2     61965.607292
# 3     67989.402129
# 4    105356.947351
# dtype: float64

# %%
in_range = series.between(65000,80000)

# %%
in_range.mean()
# Out:
# 0.33544

# %% [markdown]
# ### What do the top 5% of employees make?

# %%
stats.norm(72012,17310).ppf(.95)
# Out:
# 100484.41628252999

# %%
(employees_test > 100484.41).mean()
# Out:
# 0.05055
